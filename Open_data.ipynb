# %%
### open de data
from funciones import abrir , dibujar , reducir
v=abrir("electrones.root",(279,279,1000))

# %%
## display 10 random images
import numpy as np
display=np.random.randint(0,1000,size=(1,10))[0] 
for i in display:
    dibujar(i,v)

# %% [markdown]
# # Generation of particles
# We want to understand how $e^{-}$ and $mu^{-}$ are generated

# %%
### Dependences
import numpy as np 
import uproot 
import matplotlib.pyplot as plt

# %%
En=[]
x=[]
y=[]
z=[]
theta=[]
phi=[]
for i in range(0,10):
    file = uproot.open("gen_e/{}-Gen-Parser.root".format(i))
    tree = file["analysistree"]["anatree"] 
    En = np.append(En,tree.array(b'MCTruth_Generator_StartEnergy').flatten())
    x = np.append(x,tree.array(b'MCTruth_Generator_StartPoint_X').flatten())
    y = np.append(y,tree.array(b'MCTruth_Generator_StartPoint_Y').flatten())
    z = np.append(z,tree.array(b'MCTruth_Generator_StartPoint_Z').flatten())
    theta = np.append(theta,tree.array(b'MCTruth_Generator_StartDirection_Theta').flatten())
    phi = np.append(phi,tree.array(b'MCTruth_Generator_StartDirection_Phi').flatten())

# %%
tree=file["analysistree"]["anatree"] 
tree.keys()
# Out:
# [b'Run',
#  b'Subrun',
#  b'EventNumberInRun',
#  b'EventTimeSeconds',
#  b'EventTimeNanoseconds',
#  b'IsData',
#  b'MCTruth_Generator_NumberOfParticles',
#  b'MCTruth_Generator_ParticleID',
#  b'MCTruth_Generator_PDGCode',
#  b'MCTruth_Generator_Status',
#  b'MCTruth_Generator_Mass',
#  b'MCTruth_Generator_StartTime',
#  b'MCTruth_Generator_StartEnergy',
#  b'MCTruth_Generator_StartMomentum',
#  b'MCTruth_Generator_StartPoint_X',
#  b'MCTruth_Generator_StartPoint_Y',
#  b'MCTruth_Generator_StartPoint_Z',
#  b'MCTruth_Generator_StartMomentum_X',
#  b'MCTruth_Generator_StartMomentum_Y',
#  b'MCTruth_Generator_StartMomentum_Z',
#  b'MCTruth_Generator_StartDirection_Theta',
#  b'MCTruth_Generator_StartDirection_Phi']

# %%
fig=plt.figure()
plt.xlabel("Energy (GeV)")
plt.title("Energy")
plt.hist(En.flatten(), bins=30) ## Energy uniformly distributed from 0 to 10 GeV
plt.show()

# %%
## initialize a vector of positions

fig = plt.figure()
plt.xlabel("X (cm)")
plt.title("X")
plt.hist(x.flatten(), bins=50) ## Energy uniformly distributed from 0 to 10 GeV
plt.show()

fig = plt.figure()
plt.xlabel("Y (cm)")
plt.title("Y")
plt.hist(y.flatten(), bins=50) ## Energy uniformly distributed from 0 to 10 GeV
plt.show()

fig = plt.figure()
plt.xlabel("Z (cm)")
plt.title("Z")
plt.hist(z.flatten(), bins=50) ## Energy uniformly distributed from 0 to 10 GeV
plt.show()

fig = plt.figure()
plt.xlabel("theta ")
plt.title("theta")
plt.hist(theta.flatten(), bins=50) ## Energy uniformly distributed from 0 to 10 GeV
plt.show()

fig = plt.figure()
plt.xlabel("phi ")
plt.title("phi")
plt.hist(phi.flatten(), bins=50) ## Energy uniformly distributed from 0 to 10 GeV
plt.show()

# %%
### From where are the particles comming?

fig=plt.figure()
plt.scatter(y.flatten(), x.flatten() )
plt.xlabel("Y (cm)")
plt.xlim(-50,50)
plt.ylim(-50,55)
plt.ylabel("X (cm)")


fig=plt.figure()
plt.scatter(z.flatten(), y.flatten() )
plt.xlabel("Z (cm)")
plt.xlim(0,300)
plt.ylabel("Y (cm)")
plt.ylim(0,55)
# Out:
# (0, 55)

# %% [markdown]
# # now for muons

# %%
En=[]
x=[]
y=[]
z=[]
theta=[]
phi=[]
for i in range(0,10):
    file = uproot.open("gen_mu/{}-Gen-Parser.root".format(i))
    tree = file["analysistree"]["anatree"] 
    En = np.append(En,tree.array(b'MCTruth_Generator_StartEnergy').flatten())
    x = np.append(x,tree.array(b'MCTruth_Generator_StartPoint_X').flatten())
    y = np.append(y,tree.array(b'MCTruth_Generator_StartPoint_Y').flatten())
    z = np.append(z,tree.array(b'MCTruth_Generator_StartPoint_Z').flatten())
    theta = np.append(theta,tree.array(b'MCTruth_Generator_StartDirection_Theta').flatten())
    phi = np.append(phi,tree.array(b'MCTruth_Generator_StartDirection_Phi').flatten())

# %%
fig=plt.figure()
plt.xlabel("Energy (GeV)")
plt.title("Energy")
plt.hist(En.flatten(), bins=30) ## Energy uniformly distributed from 0 to 10 GeV
plt.show()

fig = plt.figure()
plt.xlabel("X (cm)")
plt.title("X")
plt.hist(x.flatten(), bins=50) ## Energy uniformly distributed from 0 to 10 GeV
plt.show()

fig = plt.figure()
plt.xlabel("Y (cm)")
plt.title("Y")
plt.hist(y.flatten(), bins=50) ## Energy uniformly distributed from 0 to 10 GeV
plt.show()

fig = plt.figure()
plt.xlabel("Z (cm)")
plt.title("Z")
plt.hist(z.flatten(), bins=50) ## Energy uniformly distributed from 0 to 10 GeV
plt.show()

fig = plt.figure()
plt.xlabel("theta ")
plt.title("theta")
plt.hist(theta.flatten(), bins=50) ## Energy uniformly distributed from 0 to 10 GeV
plt.show()

fig = plt.figure()
plt.xlabel("phi ")
plt.title("phi")
plt.hist(phi.flatten(), bins=50) ## Energy uniformly distributed from 0 to 10 GeV
plt.show()

fig=plt.figure()
plt.scatter(y.flatten(), x.flatten() )
plt.xlabel("Y (cm)")
plt.xlim(-50,50)
plt.ylim(-50,55)
plt.ylabel("X (cm)")


fig=plt.figure()
plt.scatter(z.flatten(), y.flatten() )
plt.xlabel("Z (cm)")
plt.xlim(0,300)
plt.ylabel("Y (cm)")
plt.ylim(0,55)
# Out:
# /usr/local/lib64/python3.6/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib64/python3.6/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (0, 55)
